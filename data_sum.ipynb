# %%
import pandas as pd

# %%
dt1 = pd.read_csv('final2.csv', index_col=0)
dt2 = pd.read_csv('final_cof_bean_pork.csv', index_col=0)

# %%
dt =pd.merge(dt1, dt2, on='date', how='left' )

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1249 entries, 0 to 1248
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1249 non-null   object
#  1   cu_cost         1249 non-null   float64
#  2   oil_cost        1244 non-null   float64
#  3   gas_cost        1244 non-null   float64
#  4   wheat_cost      1225 non-null   float64
#  5   al_cost         1197 non-null   float64
#  6   cu_vol          1197 non-null   float64
#  7   wheat_vol       1051 non-null   float64
#  8   gas_vol         1194 non-null   float64
#  9   oil_vol         1197 non-null   float64
#  10  al_vol          1157 non-null   float64
#  11  kospi_cost      1163 non-null   float64
#  12  kospi_vol       1163 non-null   float64
#  13  kospi200_cost   1163 non-null   float64
#  14  kospi200_vol    1163 non-null   float64
#  15  kosdaq_cost     1163 non-null   float64
# ...

# %%
dt.to_csv('origin_proc.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dt_drop_date = dt.drop(['date'], axis=1)

# %%
dt_vol = dt.drop(['oil_cost', 'al_cost', 'gas_cost', 'bn_cost', 'cof_cost', 'pk_cost', 'wheat_cost', 'cu_cost'], axis =1)

# %%
dt_vol.drop(['kospi200_vol', 'kosdaq_vol', 'kospi_vol', 'kosdaq100_vol'],axis=1, inplace=True)

# %%
dt_vol
# Out:
#               date    cu_vol  wheat_vol   gas_vol   oil_vol   al_vol  \
# 0     2022- 09- 30   75360.0    78140.0   97370.0   95340.0  52170.0
# 1     2022- 09- 29   86450.0    41360.0   85720.0  127460.0  81670.0
# 2     2022- 09- 28    1000.0    51300.0    1870.0  156310.0  48590.0
# 3     2022- 09- 27     180.0    48800.0  130920.0  123820.0  41900.0
# 4     2022- 09- 26     510.0    48790.0   81080.0  106230.0  37040.0
# ...            ...       ...        ...       ...       ...      ...
# 1244  2018- 01- 08   87800.0    71820.0  228240.0  296580.0  50210.0
# 1245  2018- 01- 05   84950.0    62550.0  230950.0       0.0  31430.0
# 1246  2018- 01- 04  105440.0    58730.0  319710.0      30.0  35900.0
# 1247  2018- 01- 03  104300.0    70970.0  269890.0      10.0  41070.0
# 1248  2018- 01- 02  107290.0    71350.0  320180.0     110.0  50520.0
#
#       kospi_cost  kospi200_cost  kosdaq_cost  kosdaq100_cost  cof_vol  \
# ...

# %%
dt_vol_drop_date = dt_vol.drop(['date'], axis =1)
plt.figure(figsize = (20,15))
sns.heatmap(dt_drop_date.corr(), annot=True, fmt = ".2f")
# Out:
# <AxesSubplot:>

# %%
dt_drop_date_drop_cor = dt_drop_date.drop(['cu_vol', 'wheat_vol','gas_vol','cof_vol','bn_vol','pk_vol'], axis=1)

# %%
plt.figure(figsize = (20,15))
sns.heatmap(dt_drop_date_drop_cor.corr(), annot=True, fmt = ".2f")
# Out:
# <AxesSubplot:>
